# %%
import csv
import networkx as nx
import numpy as np
import pandas as pd
import array
import tempfile
import simplestatistics as ss
import urllib
# %matplotlib inline
# library for displaying plots
import matplotlib.pyplot as plt
# display plots in the notebook
# if this is not set, you will not see the graphic here
import seaborn as sns
from scipy import stats
import matplotlib as mpl
from random import randint
from enum import Enum

#People for the simulation
COLUMNS = ['Sex','Age','BMI','TimeNormal','TimeFast','Adrenaline','Office','Floor','Path','Length']
data = pd.read_csv("output_men_magnitud1.csv", sep=",", names=COLUMNS, skipinitialspace=True)

#datasetFinales
data20 = data[(data.BMI < 20)]
data2025 = data[((data.BMI >= 20) & (data.BMI < 25))]
data2530 = data[((data.BMI >= 25) & (data.BMI < 30))]
data3035 = data[((data.BMI >= 30) & (data.BMI < 35))]
data3540 = data[((data.BMI >= 35) & (data.BMI < 40))]
data40 = data[(data.BMI >= 40)]
#print data20[(data20.Floor == 0)]
g8= sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 0) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 0) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 0) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 0) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 0) & (data40.Age == 2)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 0) & (data40.Age == 2)], kind="reg",color="b", size=7)



g8= sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 1) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 1) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 1) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 1) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 1) & (data40.Age == 2)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 1) & (data40.Age == 2)], kind="reg",color="b", size=7)


g8= sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 2) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 2) & (data40.Age == 0)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 2) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 2) & (data40.Age == 1)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeNormal", data=data40[(data40.Floor == 2) & (data40.Age == 2)], kind="reg",color="b", size=7)
g8 = sns.jointplot("BMI","TimeFast", data=data40[(data40.Floor == 2) & (data40.Age == 2)], kind="reg",color="b", size=7)




# Make a custom sequential palette using the cubehelix system
#pal = sns.cubehelix_palette(4, 1.5, .75, light=.6, dark=.2)

# Plot tip as a function of toal bill across days
#g = sns.lmplot(x="BMI", y="TimeNormal", hue="Floor", data=data20, palette=pal, size=7)
#g = sns.lmplot(x="BMI", y="TimeFast", hue="Floor", data=data20, palette=pal, size=7)
